# %% [markdown]
# # Designing a Pipeline

# %% [markdown]
# To get setup install the recommended packages from the `requirements.txt` file.

# %%
#!pip install -r requirements.txt

# %% [markdown]
# Refer to the book to cover the chapters on getting the data ingested into the Neo4J instance. This will focus on the Python elements of the process.

# %% [markdown]
# ## Simulating customer interactions

# %%
from faker import Faker

fake = Faker()
Faker.seed(0)

# %%
name = fake.name()
address = fake.address()

print(name)
print(address)
# Out:
# Norma Fisher
# 4759 William Haven Apt. 194
# West Corey, CA 90152

# %% [markdown]
# Here we will create a custom class to create some fake information based on the customerID.

# %%
from datetime import datetime

class Customer:
	def __init__(self, customerID):
		self.customerID = customerID
		self.name = fake.name()
		self.address = fake.address()
		self.datetime = datetime.now().strftime("%d/%m/%Y-%H:%M:%S")

	# Custom string override (dunder method) to print when print on new customer class is instantiated
	def __str__(self):
		return f'The customer ID is: {self.customerID}\nCustoner Name is: {self.name}\nCustomer address: {self.address}\nCreated on: {self.datetime}'

# %%
new_customer = Customer(customerID=9999)
print(new_customer)
# Out:
# The customer ID is: 9999
# Custoner Name is: Justin Gomez
# Customer address: 778 Brown Plaza
# North Jenniferfurt, VT 88077
# Created on: 19/10/2023-16:30:11

# %% [markdown]
# ### Create connection to Neo4J instance

# %%
from neo4j import GraphDatabase

class Neo4jConnect:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
        
    def close(self):
        self.driver.close()
        
    def query(self, query):
        session = self.driver.session()
        result = session.run(query)
        return result

# %% [markdown]
# For convenience - this has also been saved into the supporting package we have created.

# %%
from graphtastic.database.neo4j import Neo4jConnect

# %% [markdown]
# Next we will add customers to our Neo4J instance using the faked data:

# %%
def add_customer(c, connection):
    query = f'MERGE (:Customer {{customerID: toInteger({c.customerID}), ' \
    		f'name: "{c.name}", ' \
    		f'address: "{c.address}"}})'
    connection.query(query)

# %% [markdown]
# Test this function out with our faked data.

# %%
test_customer = Customer(9999)
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
add_customer(test_customer, connection)
connection.close()

# %% [markdown]
# Run this code in Neo4J Browser:

# %%
# %%writefile cypher/return_customers.cql
# MATCH (c:Customer) RETURN c
# Out:
# Overwriting cypher/return_customers.cql

# %%
def add_purchase(c, productID, time, connection):
	query = f'MATCH (c:Customer {{customerID: toInteger({c.customerID})}}) ' \
			f'MATCH (p:Product {{productID: toInteger({productID})}}) ' \
			f'MERGE (c)-[:PURCHASED {{datetime:"{time}"}}]->(p)'
	connection.query(query)

# %%
from datetime import datetime

connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
add_purchase(test_customer, 1010, datetime.now(), connection)
connection.close()

# %%
# %%writefile cypher/edge_bt_cust_and_purch_nodes.cql
# MATCH (c:Customer)-[:PURCHASED]->(p:Product) RETURN c, p
# Out:
# Overwriting cypher/edge_bt_cust_and_purch_nodes.cql

# %% [markdown]
# Add another purchase to the graph database:

# %%
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
add_purchase(test_customer, 1010, datetime.now(), connection)
connection.close()

# %% [markdown]
# This code will save the script we will run in Neo4J Browser:

# %%
# %%writefile cypher/get_cust_and_prod.cql
# MATCH (c:Customer)-[purchase:PURCHASED]->(p:Product)
# RETURN c.name, p.name, purchase.datetime
# Out:
# Overwriting cypher/get_cust_and_prod.cql

# %% [markdown]
# We will purge out database data with the below Cypher that will be execute in the Neo4J Browser:

# %%
# %%writefile cypher/purge_data.cql
# MATCH (c:Customer) DETACH DELETE c
# Out:
# Overwriting cypher/purge_data.cql

# %%
def get_product_ids(connection):
	query = 'MATCH (p:Product) RETURN p.productID as productID'
	result = connection.query(query).data()
	result = [product['productID'] for product in result]
	return result

# %%
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
product_ids = get_product_ids(connection)
connection.close()
print(product_ids)
print(len(product_ids))
# Out:
# [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027]
# 27

# %% [markdown]
# Generate lots of customers:

# %%
customers = [Customer(customerID) for customerID in range(10000, 10100)]

# %%
for customer in customers:
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    add_customer(customer, connection)
    connection.close()

# %%
import random

for customer in customers:
    # Print out the customer and add a line print for 
    print(customer, '\n----------------------------------------------------')
    product = random.choice(product_ids)
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    add_purchase(customer, product, datetime.now(), connection)
    connection.close()
# Out:
# The customer ID is: 10000
# Custoner Name is: Gary Nielsen
# Customer address: 1965 Kelly Field Apt. 094
# Jonesberg, FM 20102
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10001
# Custoner Name is: Sarah Villanueva
# Customer address: PSC 8684, Box 8339
# APO AA 76482
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10002
# Custoner Name is: Johnathan Davidson
# Customer address: 59179 Bruce Gardens Apt. 413
# Lauramouth, NE 08652
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10003
# Custoner Name is: Charles Wolfe
# Customer address: 13991 Davis Village
# North Catherineborough, HI 94625
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10004
# Custoner Name is: Daniel Owen
# Customer address: USS Stephens
# FPO AP 13804
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10005
# Custoner Name is: Andrea Jones
# Customer address: 08709 Holly Lock Apt. 457
# Lake Emily, WI 08109
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10006
# Custoner Name is: Brooke Martin
# Customer address: 720 Maldonado Port
# Deborahfurt, MP 86696
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10007
# Custoner Name is: Justin Smith
# Customer address: 084 John Orchard Suite 945
# Lake Kyle, WA 54819
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10008
# Custoner Name is: Angela Wheeler
# Customer address: 37696 Richard Squares
# Bartonton, GA 58874
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10009
# Custoner Name is: Michael Griffin
# Customer address: 75470 Lopez Roads
# Port Jessicatown, MO 89435
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10010
# Custoner Name is: Aaron Smith
# Customer address: 19344 Craig Walk
# Burtontown, KY 59873
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10011
# Custoner Name is: Ashley Scott
# Customer address: 24000 Erin Point Suite 590
# Josephmouth, SC 57575
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10012
# Custoner Name is: Joshua Clark
# Customer address: 24555 Matthew River
# North Josephberg, OR 38450
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10013
# Custoner Name is: William Anderson
# Customer address: 42814 Houston Hills
# Rodriguezside, PW 63569
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10014
# Custoner Name is: Ryan Cherry
# Customer address: 76045 Samantha Road Suite 111
# Lake Jeffrey, MS 01530
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10015
# Custoner Name is: Justin Roberts
# Customer address: PSC 9361, Box 5349
# APO AE 57022
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10016
# Custoner Name is: Brian Short
# Customer address: 731 Sanders Fords
# Port Jasonberg, CT 26449
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10017
# Custoner Name is: Isaiah Wilcox
# Customer address: 96687 Bass Parks Apt. 893
# West Janicemouth, GU 42683
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10018
# Custoner Name is: Charles Scott
# Customer address: 471 Zachary Canyon Apt. 320
# Alexismouth, MA 21562
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10019
# Custoner Name is: Sheila Murray
# Customer address: 809 Erika Valley Apt. 634
# Petersenfort, PR 51431
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10020
# Custoner Name is: Cynthia Hancock
# Customer address: 248 Cook Park
# Sherriport, WI 53987
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10021
# Custoner Name is: James Martin
# Customer address: USNS Mitchell
# FPO AA 07779
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10022
# Custoner Name is: Karen Thomas
# Customer address: 256 Cheryl Lights
# Williamsfort, WI 20341
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10023
# Custoner Name is: Kyle Anderson
# Customer address: 67109 Mendez Junction Apt. 942
# Lloydville, NC 25290
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10024
# Custoner Name is: James Watson
# Customer address: 100 Scott Burg Apt. 318
# Hunterville, FL 56333
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10025
# Custoner Name is: Jennifer Miller
# Customer address: 62076 Johnson Way
# Jenniferland, MI 09719
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10026
# Custoner Name is: Michael Reed
# Customer address: 1923 Jamie Spring
# Lake Adrianstad, UT 03731
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10027
# Custoner Name is: Crystal Thomas
# Customer address: 4203 Rogers Highway Suite 852
# North Amandaport, GA 49861
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10028
# Custoner Name is: Theresa Brock
# Customer address: 24560 Carolyn Lock
# Lake Charleschester, ME 72692
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10029
# Custoner Name is: Timothy Garza
# Customer address: 37580 Ortiz Mall Suite 735
# Stephanieland, HI 14737
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10030
# Custoner Name is: Justin Watts
# Customer address: 2662 Susan Junctions Apt. 571
# Fischerport, AL 92119
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10031
# Custoner Name is: Joel Robinson
# Customer address: 926 Davis Parks Apt. 864
# North Josephton, AL 34130
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10032
# Custoner Name is: Steve Mckinney
# Customer address: 4391 Chad Greens Suite 851
# Port Frank, MT 38471
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10033
# Custoner Name is: Chad Mills
# Customer address: 8644 Watson Road
# East David, DE 50495
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10034
# Custoner Name is: John Castro
# Customer address: 637 Neal Island Suite 074
# Lake Tyler, FM 81915
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10035
# Custoner Name is: Henry Myers
# Customer address: Unit 8116 Box 0501
# DPO AP 00991
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10036
# Custoner Name is: Dr. Melissa Acosta MD
# Customer address: 16756 Mark Rue Suite 272
# Davidburgh, NV 46267
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10037
# Custoner Name is: Jasmine Roman
# Customer address: 73906 Jim Corner
# West Brian, SC 89301
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10038
# Custoner Name is: Leslie Salazar
# Customer address: 6708 Carpenter Overpass Suite 735
# Bobbyton, GA 46350
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10039
# Custoner Name is: Matthew Taylor
# Customer address: 683 Lee Rest
# New Nicolemouth, MD 70742
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10040
# Custoner Name is: Frederick Johnson
# Customer address: 38533 Chambers Street Suite 486
# Timothybury, AZ 40584
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10041
# Custoner Name is: Andrea Murray
# Customer address: 7771 Christopher Courts
# South Nicole, IL 58256
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10042
# Custoner Name is: Sabrina Hansen
# Customer address: 23732 Michael Island Suite 184
# Lake Kenneth, NV 67876
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10043
# Custoner Name is: Kimberly Green
# Customer address: 126 Jeffery Street
# Lake Amandachester, PR 07024
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10044
# Custoner Name is: Matthew Wilson
# Customer address: 84331 Leonard Fort Suite 749
# East Lisa, OH 66672
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10045
# Custoner Name is: Kevin Johnson
# Customer address: 28123 Hudson Square Apt. 323
# Gomezshire, DC 82943
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10046
# Custoner Name is: Dr. Luis Johnson MD
# Customer address: 38277 Padilla Common Suite 296
# Port Leslie, LA 50844
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10047
# Custoner Name is: Christine Edwards
# Customer address: 7345 Kevin Knolls
# Lake Crystalstad, AK 64871
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10048
# Custoner Name is: Allison Williams
# Customer address: 05623 Graham Knolls Suite 256
# Smithview, ND 70144
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10049
# Custoner Name is: Veronica Bush
# Customer address: 6208 Christy Shore
# North Mark, MP 23605
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10050
# Custoner Name is: Alex Drake
# Customer address: 169 Christine Mount
# New Carolyn, KS 45098
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10051
# Custoner Name is: Morgan Johnson
# Customer address: USS Crawford
# FPO AA 38870
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10052
# Custoner Name is: Judith Romero
# Customer address: 4760 Moreno Heights Suite 089
# Sarahton, NH 52282
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10053
# Custoner Name is: Jennifer Crawford
# Customer address: 9438 Hughes Village
# Jasonshire, MA 32305
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10054
# Custoner Name is: Michelle Maldonado
# Customer address: 0909 Stephanie Lake
# Conniemouth, NM 53409
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10055
# Custoner Name is: Victoria Smith
# Customer address: 2507 Burgess Field
# New Sharonview, MP 23285
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10056
# Custoner Name is: Amy Fowler
# Customer address: 4440 Osborne Viaduct Suite 488
# Veronicaborough, VT 57084
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10057
# Custoner Name is: Sarah Brady
# Customer address: 7086 Rachel Lake Apt. 357
# Lake Jillshire, MH 32230
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10058
# Custoner Name is: Tony House
# Customer address: 78132 Mclean Meadow Suite 446
# Chelsealand, ME 04450
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10059
# Custoner Name is: Phillip Harris MD
# Customer address: 097 Gallegos Crossroad Suite 506
# Mccallberg, AZ 11181
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10060
# Custoner Name is: Hannah Smith
# Customer address: 870 Hebert Vista
# West Philipberg, WV 83806
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10061
# Custoner Name is: Michael Larson
# Customer address: 022 Renee Squares Apt. 808
# Herringstad, AS 77293
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10062
# Custoner Name is: Angela Thompson
# Customer address: 4487 Katherine Mission Apt. 092
# Port Leslieland, ID 85488
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10063
# Custoner Name is: Lisa Burnett
# Customer address: 278 Amy View Suite 011
# Lawsonshire, NV 44515
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10064
# Custoner Name is: Kayla Archer
# Customer address: 50220 Blackwell Fields
# South Deannaport, WY 51555
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10065
# Custoner Name is: Lindsay Bauer
# Customer address: 0759 Chambers Port
# Gutierreztown, NH 35123
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10066
# Custoner Name is: James Howard
# Customer address: 26905 Gibbs Summit Suite 710
# Gibbsview, AK 85435
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10067
# Custoner Name is: Sara Miller
# Customer address: 0284 Aaron Junction
# New Heather, GA 23388
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10068
# Custoner Name is: Caitlin Frazier
# Customer address: USNV Dougherty
# FPO AA 82530
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10069
# Custoner Name is: Amanda Allen
# Customer address: 53267 Walter Dam
# Cunninghamtown, GA 77001
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10070
# Custoner Name is: James Solis
# Customer address: Unit 0058 Box 0001
# DPO AP 80648
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10071
# Custoner Name is: Christian Buchanan
# Customer address: 9532 Dixon Place Suite 126
# Tammychester, MH 57653
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10072
# Custoner Name is: James Hendricks
# Customer address: 9144 Daniels Rapids Suite 340
# Michellefurt, SC 14481
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10073
# Custoner Name is: Sarah Thomas
# Customer address: 661 Munoz Estates Apt. 576
# New Samantha, VI 37687
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10074
# Custoner Name is: Ashley Richardson
# Customer address: 8034 Jennifer Islands Suite 604
# Johnsonchester, KY 49674
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10075
# Custoner Name is: Hannah Anderson
# Customer address: 69671 Kimberly Plains
# East Eric, GA 30418
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10076
# Custoner Name is: Chad Snyder
# Customer address: PSC 9451, Box 6425
# APO AP 66241
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10077
# Custoner Name is: Kim Thomas
# Customer address: 65678 Oconnell Lodge Apt. 220
# Lake Kimberlyborough, PA 84950
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10078
# Custoner Name is: Kayla Adams
# Customer address: 1001 Roth Orchard
# Danielmouth, MN 77080
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10079
# Custoner Name is: Mary Burnett
# Customer address: 818 Anthony Row
# New Robert, TN 27774
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10080
# Custoner Name is: Michael Baker
# Customer address: 79061 Cook Parkways Suite 079
# West Marissafort, OH 85040
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10081
# Custoner Name is: Derek Hall
# Customer address: 271 Timothy Port Suite 814
# Hallville, LA 18991
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10082
# Custoner Name is: Brandon Barrett
# Customer address: 830 Michelle Point
# Kleinville, NJ 73841
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10083
# Custoner Name is: Richard Brennan
# Customer address: 74430 Kelly Pass
# Christopherport, OK 55851
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10084
# Custoner Name is: Jacob James
# Customer address: 3754 Salazar Village
# South Michaelfort, IN 86508
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10085
# Custoner Name is: Lynn Howard
# Customer address: 417 Martinez Drives Suite 325
# Perezfurt, MS 61425
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10086
# Custoner Name is: Veronica Bray
# Customer address: 684 Hall Path
# North Thomasfurt, MH 30303
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10087
# Custoner Name is: Jessica Williams
# Customer address: 43521 Laura Lakes Apt. 300
# Nicholsberg, DE 79753
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10088
# Custoner Name is: Susan Miller
# Customer address: 961 Sara Forks
# Reyestown, NE 28039
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10089
# Custoner Name is: Preston Gilbert
# Customer address: 557 Caitlin Course Suite 114
# Lake Donaldberg, MS 27644
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10090
# Custoner Name is: Mary Harris
# Customer address: 171 Harrison Motorway
# Davidview, MS 10796
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10091
# Custoner Name is: Gabriela Short
# Customer address: 7607 Andrea Track
# Walkerbury, KS 63052
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10092
# Custoner Name is: Darren Campbell
# Customer address: 134 Sophia Drives
# Benjaminburgh, WI 61921
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10093
# Custoner Name is: Cody Crawford
# Customer address: 8352 Hernandez Spurs
# Nolanshire, IL 78890
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10094
# Custoner Name is: David Stein
# Customer address: 00237 Donna Coves
# Middletonport, FM 90026
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10095
# Custoner Name is: Michael Martin
# Customer address: 767 Singleton Mountain Apt. 231
# South Stephanie, VT 71357
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10096
# Custoner Name is: Jacob Williams
# Customer address: 9968 Cynthia Skyway
# New Dawn, NM 40953
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10097
# Custoner Name is: Joshua Miller
# Customer address: Unit 7036 Box 9541
# DPO AP 03546
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10098
# Custoner Name is: Cynthia Faulkner
# Customer address: 74197 Humphrey Forges Suite 685
# Port Brittany, CO 06269
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------
# The customer ID is: 10099
# Custoner Name is: Mark Elliott
# Customer address: 5601 Lawson Dale Apt. 016
# North Crystal, KS 50871
# Created on: 19/10/2023-16:34:13
# ----------------------------------------------------

# %%
from time import sleep
sleep(1)

# %% [markdown]
# # Making Recommendations

# %%
def rec_by_brand(c, connection):
    query = f'MATCH (c:Customer {{customerID: toInteger({c.customerID})}})' \
            '-[:PURCHASED]->(p:Product)' \
            'MATCH (p)-[:HAS_BRAND]->(b:Brand)' \
            'MATCH (b)<-[:HAS_BRAND]-(r:Product)' \
            'WHERE NOT (c)-[:PURCHASED]->(r)' \
            'RETURN DISTINCT r.productID as productID'
    
    result = connection.query(query).data()
    result = [product['productID'] for product in result]


    return result

# %%
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
print(connection)

# %%
brand_recommendations = rec_by_brand(customers[10], connection)
connection.close()
print(brand_recommendations)

# %% [markdown]
# Use the Cypher in Neo4J Browser to get the results:

# %%
# %%writefile cypher/cust_brand_prod.cql
# MATCH (c:Customer {customerID:10010})-[:PURCHASED]->(p:Product)
# MATCH (p)-[:HAS_BRAND]->(b:Brand)
# MATCH (b)<-[:HAS_BRAND]-(r:Product)
# WHERE NOT (c)-[:PURCHASED]->(r)
# RETURN c, p, b, r

# %%
for customer in customers:
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    brand_recommendations = rec_by_brand(customer, connection)
    connection.close()
    if len(brand_recommendations) != 0:
        product = random.choice(brand_recommendations)
        connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
        add_purchase(customer, product, datetime.now(), connection)
        connection.close()

# %% [markdown]
# Execute cypher to see if this has worked correctly:

# %%
# %%writefile cypher/distinct_product_match.cql
# MATCH (c:Customer {customerID:10010})-[:PURCHASED]->(p:Product)
# MATCH (p)-[:HAS_TYPE]->(st:Type)
# MATCH (p)-[:HAS_BRAND]->(b:Brand)
# MATCH (b)<-[:HAS_BRAND]-(r:Product)
# WHERE NOT (c)-[:PURCHASED]->(r) AND (r)-[:HAS_TYPE]->(st)
# RETURN DISTINCT r

# %% [markdown]
# ## Drawing on other customers purchases

# %%
def rec_by_copurchase(c, connection):
    query = f'MATCH (c:Customer {{customerID: toInteger({c.customerID})}})' \
            '-[:PURCHASED]->(p:Product)' \
            'MATCH (p)<-[:PURCHASED]-(c2:Customer)' \
            'WHERE c2 <> c ' \
            'MATCH (c2)-[:PURCHASED]->(r:Product)' \
            'WHERE p <> r ' \
            'RETURN DISTINCT r.productID as productID'
    result = connection.query(query).data()
    result = [product['productID'] for product in result]
    return result

# %%
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
copurchase_recommendations = rec_by_copurchase(customers[10], connection)
connection.close()
print(copurchase_recommendations)

# %%
for customer in customers:
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    copurchase_recommendations = rec_by_copurchase(customer, connection)
    connection.close()
    if len(copurchase_recommendations) != 0:
        product = random.choice(copurchase_recommendations)
        connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
        add_purchase(customer, product, datetime.now(), connection)
        connection.close()

# %% [markdown]
# ## Using similarity scores to recommend products

# %%
def get_customer_purchases(c_id, connection):
    query = f'MATCH (c:Customer {{customerID: toInteger({c_id})}})' \
            '-[:PURCHASED]->(p:Product)' \
            'RETURN DISTINCT p.productID as productID'
    result = connection.query(query).data()
    result = [product['productID'] for product in result]
    return result

# %%
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
purchases = get_customer_purchases(customers[10].customerID, connection)
connection.close()
print(purchases)

# %% [markdown]
# This code to be run in `Neo4J Browser`:

# %%
# %%writefile cypher/cust_purchases.cql
# MATCH (c:Customer {customerID:10010})-[:PURCHASED]-(p:Product)
# RETURN DISTINCT p.productID as productID

# %%
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
all_purchases = {customer.customerID: get_customer_purchases(customer.customerID, connection) 
                 for customer in customers}

# %%
print(all_purchases)

# %%
def jaccard_similarity(list1, list2):
    set1 = set(list1)
    set2 = set(list2)
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    jaccard = len(intersection) / len(union)
    return jaccard

# %%
list1 = [1, 2, 3, 4]
list2 = [5, 6, 7, 8]
list3 = [1, 2]
assert jaccard_similarity(list1, list1) == 1
assert jaccard_similarity(list1, list2) == 0
assert jaccard_similarity(list1, list3) == 0.5

# %%
import itertools
customer_ids = list(all_purchases.keys())
print(customer_ids)
customer_pairs = list(itertools.combinations(customer_ids, 2))
print(customer_pairs[:10])

# %%
similarity = {pair: jaccard_similarity(all_purchases[pair[0]], all_purchases[pair[1]]) for pair in customer_pairs}
print(similarity)

# %%
from collections import Counter
grouped_similiarities = Counter(similarity.values())
print(grouped_similiarities)

# %%
def add_purchase_id(c_id, productID, time, connection):
	query = f'MATCH (c:Customer {{customerID: toInteger({c_id})}}) ' \
			f'MATCH (p:Product {{productID: toInteger({productID})}}) ' \
			f'MERGE (c)-[:PURCHASED {{datetime:"{time}"}}]->(p)'
	connection.query(query)

# %%
threshold = 0.7

# %%
def rec_by_similarity(c1, c2, threshold, connection):
    p1 = get_customer_purchases(c1, connection)
    p2 = get_customer_purchases(c2, connection)
    similarity = jaccard_similarity(p1, p2)
    if similarity >= threshold and similarity != 1:
        p1_recs = [p for p in p2 if p not in p1]
        p2_recs = [p for p in p1 if p not in p2]
        for p in p1_recs:
            add_purchase_id(c1, p, datetime.now(), connection)
        for p in p2_recs:
            add_purchase_id(c2, p, datetime.now(), connection)

# %%
for pair in customer_pairs:
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    rec_by_similarity(pair[0], pair[1], 0.7, connection)
    connection.close()

# %% [markdown]
# ## Complete Python script

# %%
# %%writefile pipeline_dev.py
from faker import Faker
from datetime import datetime
from graphtastic.database.neo4j import Neo4jConnect
import random

# Fake some data
fake = Faker()
Faker.seed(0)
# Get faker atrributes
name = fake.name()
address = fake.address()
print(name)
print(address)

# Create a class we will use to generate new customers
class Customer:
	def __init__(self, customerID):
		self.customerID = customerID
		self.name = fake.name()
		self.address = fake.address()
		self.datetime = datetime.now().strftime("%d/%m/%Y-%H:%M:%S")

	# Custom string override (dunder method) to print when print on new customer class is instantiated
	def __str__(self):
		return f'The customer ID is: {self.customerID}\nCustoner Name is: {self.name}\nCustomer address: {self.address}\nCreated on: {self.datetime}'
   

# Instantiate customer
new_customer = Customer(customerID=9999)
print(new_customer)

# Create add customer function
def add_customer(c, connection):
    query = f'MERGE (:Customer {{customerID: toInteger({c.customerID}), ' \
    		f'name: "{c.name}", ' \
    		f'address: "{c.address}"}})'
    connection.query(query)

# Create customer in Neo4J
test_customer = Customer(9999)
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
add_customer(test_customer, connection)
connection.close()

# Create function to add a purchase to Neo4J
def add_purchase(c, productID, time, connection):
	query = f'MATCH (c:Customer {{customerID: toInteger({c.customerID})}}) ' \
			f'MATCH (p:Product {{productID: toInteger({productID})}}) ' \
			f'MERGE (c)-[:PURCHASED {{datetime:"{time}"}}]->(p)'
	connection.query(query)

# Use add purchase to add purchases for our test customer
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
add_purchase(test_customer, 1010, datetime.now(), connection)
connection.close()

# Add another purchase
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
add_purchase(test_customer, 1010, datetime.now(), connection)
connection.close()

# Create function to get product ids
def get_product_ids(connection):
	query = 'MATCH (p:Product) RETURN p.productID as productID'
	result = connection.query(query).data()
	result = [product['productID'] for product in result]
	return result

# Get product IDS from Neo4J
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
product_ids = get_product_ids(connection)
connection.close()
print(product_ids)
print(len(product_ids))

# Generate lots of customers
customers = [Customer(customerID) for customerID in range(10000, 10100)]
for customer in customers:
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    add_customer(customer, connection)
    connection.close()

# Create purchases at random for our customers
for customer in customers:
    # Print out the customer and add a line print for 
    print(customer, '\n----------------------------------------------------')
    product = random.choice(product_ids)
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    add_purchase(customer, product, datetime.now(), connection)
    connection.close()

# MAKING RECOMMENDATIONS
def rec_by_brand(c, connection):
    query = f'MATCH (c:Customer {{customerID: toInteger({c.customerID})}})' \
            '-[:PURCHASED]->(p:Product)' \
            'MATCH (p)-[:HAS_BRAND]->(b:Brand)' \
            'MATCH (b)<-[:HAS_BRAND]-(r:Product)' \
            'WHERE NOT (c)-[:PURCHASED]->(r)' \
            'RETURN DISTINCT r.productID as productID'
    
    result = connection.query(query).data()
    result = [product['productID'] for product in result]
    return result

connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
print(connection)

# Use function to get recommendations by brand
brand_recommendations = rec_by_brand(customers[10], connection)
connection.close()
print(brand_recommendations)

for customer in customers:
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    brand_recommendations = rec_by_brand(customer, connection)
    connection.close()
    if len(brand_recommendations) != 0:
        product = random.choice(brand_recommendations)
        connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
        add_purchase(customer, product, datetime.now(), connection)
        connection.close()

# Drawing on other customers purchases
def rec_by_copurchase(c, connection):
    query = f'MATCH (c:Customer {{customerID: toInteger({c.customerID})}})' \
            '-[:PURCHASED]->(p:Product)' \
            'MATCH (p)<-[:PURCHASED]-(c2:Customer)' \
            'WHERE c2 <> c ' \
            'MATCH (c2)-[:PURCHASED]->(r:Product)' \
            'WHERE p <> r ' \
            'RETURN DISTINCT r.productID as productID'
    result = connection.query(query).data()
    result = [product['productID'] for product in result]
    return result

# Look at recommending products based on other customers recommendations
connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
copurchase_recommendations = rec_by_copurchase(customers[10], connection)
connection.close()
print(copurchase_recommendations)

for customer in customers:
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    copurchase_recommendations = rec_by_copurchase(customer, connection)
    connection.close()
    if len(copurchase_recommendations) != 0:
        product = random.choice(copurchase_recommendations)
        connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
        add_purchase(customer, product, datetime.now(), connection)
        connection.close()

# Use similarity scores to recommend products
def get_customer_purchases(c_id, connection):
    query = f'MATCH (c:Customer {{customerID: toInteger({c_id})}})' \
            '-[:PURCHASED]->(p:Product)' \
            'RETURN DISTINCT p.productID as productID'
    result = connection.query(query).data()
    result = [product['productID'] for product in result]
    return result

connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
purchases = get_customer_purchases(customers[10].customerID, connection)
connection.close()
print(purchases)

connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
all_purchases = {customer.customerID: get_customer_purchases(customer.customerID, connection) 
                 for customer in customers}

print(all_purchases)

# Create Jaccard similarity to look at similar purchases
def jaccard_similarity(list1, list2):
    set1 = set(list1)
    set2 = set(list2)
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    jaccard = len(intersection) / len(union)
    return jaccard

list1 = [1, 2, 3, 4]
list2 = [5, 6, 7, 8]
list3 = [1, 2]
assert jaccard_similarity(list1, list1) == 1
assert jaccard_similarity(list1, list2) == 0
assert jaccard_similarity(list1, list3) == 0.5

import itertools
customer_ids = list(all_purchases.keys())
print(customer_ids)
customer_pairs = list(itertools.combinations(customer_ids, 2))
print(customer_pairs[:10])

# Get similarity
similarity = {pair: jaccard_similarity(all_purchases[pair[0]], all_purchases[pair[1]]) for pair in customer_pairs}
print(similarity)

from collections import Counter
grouped_similiarities = Counter(similarity.values())
print(grouped_similiarities)

def add_purchase_id(c_id, productID, time, connection):
	query = f'MATCH (c:Customer {{customerID: toInteger({c_id})}}) ' \
			f'MATCH (p:Product {{productID: toInteger({productID})}}) ' \
			f'MERGE (c)-[:PURCHASED {{datetime:"{time}"}}]->(p)'
	connection.query(query)

threshold = 0.7

def rec_by_similarity(c1, c2, threshold, connection):
    p1 = get_customer_purchases(c1, connection)
    p2 = get_customer_purchases(c2, connection)
    similarity = jaccard_similarity(p1, p2)
    if similarity >= threshold and similarity != 1:
        p1_recs = [p for p in p2 if p not in p1]
        p2_recs = [p for p in p1 if p not in p2]
        for p in p1_recs:
            add_purchase_id(c1, p, datetime.now(), connection)
        for p in p2_recs:
            add_purchase_id(c2, p, datetime.now(), connection)

for pair in customer_pairs:
    connection = Neo4jConnect('bolt://localhost:7687', 'admin', 'testpython')
    rec_by_similarity(pair[0], pair[1], 0.7, connection)
    connection.close()
